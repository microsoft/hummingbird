# %%
import torch
import numpy as np
import lightgbm as lgb
from hummingbird.ml import convert

# Create some random data for binary classification.
num_classes = 2
X = np.array(np.random.rand(200000, 28), dtype=np.float32)
y = np.random.randint(num_classes, size=200000)

# %%
# Create and train a model (LightGBM in this case).
model = lgb.LGBMClassifier()
model.fit(X, y)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# Use Hummingbird to convert the model to PyTorch.
hb_model = convert(model, 'pytorch')
# Out:
# Finished loading model, total used 100 iterations

# %%
# %%timeit -r 3

# Run Hummingbird on CPU - By default CPU execution is used in Hummingbird.
hb_model.predict(X)
# Out:
# 3.5 s ± 20.7 ms per loop (mean ± std. dev. of 3 runs, 1 loop each)

# %%
# %%timeit -r 3

# Run Hummingbird on GPU (Note that you must have a GPU-enabled machine).
hb_model.to('cuda')
hb_model.predict(X)
# Out:
# 91.9 ms ± 1.51 ms per loop (mean ± std. dev. of 3 runs, 1 loop each)
